# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data.csv', sep=';', low_memory=False)

# %%
df.head()
# Out:
#                  Регион   Год  \
# 0  Российская Федерация  2013
# 1  Российская Федерация  2014
# 2  Российская Федерация  2014
# 3  Российская Федерация  2014
# 4  Российская Федерация  2014
#
#                                             Параметр  \
# 0  Введено в действие установок для улавливания и...
# 1                        Охрана атмосферного воздуха
# 2                        Охрана атмосферного воздуха
# 3                        Охрана атмосферного воздуха
# 4                        Охрана атмосферного воздуха
#
#                                                 CEPA  \
# 0  Охрана атмосферного воздуха и проблемы изменен...
# 1  Охрана атмосферного воздуха и проблемы изменен...
# 2  Охрана атмосферного воздуха и проблемы изменен...
# 3  Охрана атмосферного воздуха и проблемы изменен...
# 4  Охрана атмосферного воздуха и проблемы изменен...
#
#   Классификатор видов экономической деятельности (ОКВЭД)  \
# 0                                  ОКВЭД_01_ОКВЭД_02
# ...

# %%
df.isna().sum()
# Out:
# Регион                                                        0
# Год                                                           0
# Параметр                                                      0
# CEPA                                                      39076
# Классификатор видов экономической деятельности (ОКВЭД)    10334
# Источники финансирования                                  10334
# Сектора деятельности                                      70694
# Значение                                                      0
# dtype: int64

# %%
df['CEPA'].value_counts(dropna=False)
# Out:
# Очистка сточных вод                                           57246
# NaN                                                           39076
# Защита и реабилитация почвы, подземных и поверхностных вод    23280
# Охрана атмосферного воздуха и проблемы изменения климата      23050
# Сохранение биоразнообразия и среды обитания                    9251
# Обращение с отходами                                           5347
# Name: CEPA, dtype: int64

# %%
df['Классификатор видов экономической деятельности (ОКВЭД)'].value_counts(dropna=False)
# Out:
# Всего                                                                                                  25995
# NaN                                                                                                    10334
# Обрабатывающие производства                                                                             7657
# Добыча полезных ископаемых                                                                              5215
# Обеспечение электрической энергией, газом и паром; кондиционирование воздуха                            4573
#                                                                                                        ...
# Производство листов для облицовки, шпона для фанеры                                                        9
# Деятельность зоопарков                                                                                     9
# Производство оружия и боеприпасов                                                                          9
# ...

# %%
df['Источники финансирования'].value_counts(dropna=False)
# Out:
# Всего                                     107824
# Собственные средства организаций           24957
# NaN                                        10334
# Бюджет субъектов РФ и местных бюджетов      5933
# Федеральный бюджет                          5624
# Экологические фонды                         2348
# Бюджеты субъектов Российской Федерации       230
# Name: Источники финансирования, dtype: int64

# %%
df['Сектора деятельности'].value_counts(dropna=False)
# Out:
# Всего                     82196
# NaN                       70694
# Государственный сектор     4360
# Name: Сектора деятельности, dtype: int64

# %%
df[df.duplicated()]
# Out:
#                                                    Регион   Год  \
# 4171                                 Российская Федерация  2009
# 6266                                 Российская Федерация  2009
# 9869                        Центральный Федеральный округ  2009
# 16957                                  Московская область  2014
# 16961                                  Московская область  2015
# ...                                                   ...   ...
# 144905  Тюменская область (кроме Ханты-Мансийского авт...  2018
# 144913  Тюменская область (кроме Ханты-Мансийского авт...  2018
# 144915  Тюменская область (кроме Ханты-Мансийского авт...  2018
# 144923  Тюменская область (кроме Ханты-Мансийского авт...  2018
# 144928  Тюменская область (кроме Ханты-Мансийского авт...  2018
#
#                                                  Параметр  \
# 4171    Установки (производства) для утилизации и пере...
# 6266    Установки (производства) для утилизации и пере...
# ...

# %%
unique_values = pd.DataFrame(
    columns=['Unique Values'])
for row in list(df.columns.values):
    unique_values.loc[row] = [df[row].nunique()]
    
unique_values
# Out:
#                                                    Unique Values
# Регион                                                       128
# Год                                                           29
# Параметр                                                      49
# CEPA                                                           5
# Классификатор видов экономической деятельности ...           579
# Источники финансирования                                       6
# Сектора деятельности                                           2
# Значение                                                   50089

# %%
import scipy as scipy
from scipy import stats

# %%
stat, p = scipy.stats.normaltest(df['Год']) # Критерий согласия Пирсона
if p > alpha:
    print('Принять гипотезу о нормальности')
else:
    print('Отклонить гипотезу о нормальности')
# Out:
# Отклонить гипотезу о нормальности
